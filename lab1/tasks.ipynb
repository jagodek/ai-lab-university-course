# %% [markdown]
# TASK 1

# %%
import pandas as pd
import missingno

train_data = pd.read_csv("titanic.csv")
missingno.bar(train_data)
# Out:
# <AxesSubplot: >

# %% [markdown]
# TASK 2

# %%
train_data_2 = train_data.copy(deep=True)
mean = train_data_2['Age'].mean()
train_data_2["Age"].fillna(value=mean, inplace=True)

# %%
missingno.bar(train_data_2)
# Out:
# <AxesSubplot: >
